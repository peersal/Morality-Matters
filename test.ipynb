# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/results_test.csv")

# %%
data
# Out:
#       Scenario   Variation                                             Prompt  \
# 0       Switch  1v1 Worker  Consider following szenario where you are the ...
# 1         Loop  1v1 Worker  Consider following szenario where you are the ...
# 2   Footbridge  1v1 Worker  Consider following szenario where you are the ...
# 3       Switch  5v5 Worker  Consider following szenario where you are the ...
# 4         Loop  5v5 Worker  Consider following szenario where you are the ...
# 5   Footbridge  5v5 Worker  Consider following szenario where you are the ...
# 6       Switch   1v1 Apple  Consider following szenario where you are the ...
# 7         Loop   1v1 Apple  Consider following szenario where you are the ...
# 8   Footbridge   1v1 Apple  Consider following szenario where you are the ...
# 9       Switch   5v5 Apple  Consider following szenario where you are the ...
# 10        Loop   5v5 Apple  Consider following szenario where you are the ...
# ...

# %%
# Filter data for workers and apples if present
worker_data = data[data['Variation'].str.contains('Worker')]
apple_data = data[data['Variation'].str.contains('Apple')]  # If there are any apple variations

# Prepare data for plotting
# For workers
worker_grouped = worker_data.groupby(['Scenario', 'Variation'])['Act Ratio', 'Dont Act Ratio'].mean().reset_index()

# Plot settings
plt.figure(figsize=(14, 8))

# Plot for workers
sns.barplot(x='Scenario', y='Act Ratio', hue='Variation', data=worker_grouped)
plt.title('Comparison of Act Ratios between 1v1 and 5v5 for Workers', fontsize=24)
plt.ylabel('Average Act Ratio', fontsize=20)
plt.xlabel('Scenario', fontsize=20)
plt.legend(title='Variation',title_fontsize=18, fontsize=16)
plt.xticks(rotation=45, fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.savefig("plots/quantity_test1.png")
plt.show()

# Check if there is apple data to decide on plotting for apples
apple_data_present = not apple_data.empty
apple_data_present
# Out:
# C:\Users\Peer Saleth\AppData\Local\Temp\ipykernel_11168\1693952058.py:7: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   worker_grouped = worker_data.groupby(['Scenario', 'Variation'])['Act Ratio', 'Dont Act Ratio'].mean().reset_index()
# True

# %%
# Prepare data for plotting for apples
apple_grouped = apple_data.groupby(['Scenario', 'Variation'])['Act Ratio', 'Dont Act Ratio'].mean().reset_index()

# Plot settings
plt.figure(figsize=(14, 8))

# Plot for apples
sns.barplot(x='Scenario', y='Act Ratio', hue='Variation', data=apple_grouped)
plt.title('Comparison of Act Ratios between 1v1 and 5v5 for Apples', fontsize=24)
plt.ylabel('Average Act Ratio', fontsize=20)
plt.xlabel('Scenario', fontsize=20)
plt.legend(title='Variation',title_fontsize=18, fontsize=16)
plt.xticks(rotation=45, fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.savefig("plots/quantity_test2.png")
plt.show()
# Out:
# C:\Users\Peer Saleth\AppData\Local\Temp\ipykernel_11168\2904625942.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   apple_grouped = apple_data.groupby(['Scenario', 'Variation'])['Act Ratio', 'Dont Act Ratio'].mean().reset_index()

# %%
# Correcting the filter to include the proper variations for 1v5 and 5v1
variations_to_include = ['1v5', '5v1']
filtered_data = data[data['Variation'].isin(variations_to_include)]

# Prepare data for plotting for the corrected variations
filtered_grouped = filtered_data.groupby(['Scenario', 'Variation'])['Act Ratio', 'Dont Act Ratio'].mean().reset_index()

# Plot settings for the corrected variations
plt.figure(figsize=(14, 8))

# Plot for 1v5 and 5v1 variations
sns.barplot(x='Scenario', y='Act Ratio', hue='Variation', data=filtered_grouped)
plt.title('Comparison of Act Ratios between 1v5 and 5v1 Variations',  fontsize=24)
plt.ylabel('Average Act Ratio', fontsize=20)
plt.xlabel('Scenario', fontsize=20)
plt.legend(title='Variation',title_fontsize=18, fontsize=16)
plt.xticks(rotation=45, fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.savefig("plots/order_test2.png")
plt.show()
# Out:
# C:\Users\Peer Saleth\AppData\Local\Temp\ipykernel_11168\2566531450.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   filtered_grouped = filtered_data.groupby(['Scenario', 'Variation'])['Act Ratio', 'Dont Act Ratio'].mean().reset_index()
